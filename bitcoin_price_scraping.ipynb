# %%
import pandas as pd
import numpy as np
import yfinance as yf
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/legiangnam/Documents/Study/20231/GR2/crypto_currency_analysis/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
data = yf.download(tickers='BTC-USD', period='24h', interval='5m')
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2023-11-20 17:40:00+00:00  37428.730469  37431.082031  37363.175781
# 2023-11-20 17:45:00+00:00  37416.378906  37726.152344  37416.378906
# 2023-11-20 17:50:00+00:00  37700.316406  37756.820312  37693.671875
# 2023-11-20 17:55:00+00:00  37614.957031  37703.925781  37604.859375
# 2023-11-20 18:00:00+00:00  37599.191406  37683.562500  37595.574219
# ...                                 ...           ...           ...
# 2023-11-21 17:20:00+00:00  37414.312500  37504.339844  37400.980469
# 2023-11-21 17:25:00+00:00  37399.187500  37424.222656  37347.957031
# 2023-11-21 17:30:00+00:00  37307.707031  37328.156250  37224.011719
# 2023-11-21 17:35:00+00:00  37169.886719  37169.886719  37017.886719
# 2023-11-21 17:40:00+00:00  37052.632812  37052.632812  37052.632812
#
#                                   Close     Adj Close     Volume
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 289 entries, 2023-11-20 17:40:00+00:00 to 2023-11-21 17:40:00+00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       289 non-null    float64
#  1   High       289 non-null    float64
#  2   Low        289 non-null    float64
#  3   Close      289 non-null    float64
#  4   Adj Close  289 non-null    float64
#  5   Volume     289 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 15.8 KB

# %%
data.to_csv('./data/bitcoin_data.csv')
